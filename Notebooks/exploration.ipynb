# %% [markdown]
# ### Inspecting Raw Data

# %%
import pandas as pd

# %%
df = pd.read_excel("../sampleData/Orders-With Nulls.xlsx")

# %%
df.head()
# Out:
#    Order ID Order Date  Order Quantity      Sales       Ship Mode    Profit  \
# 0         3 2010-10-13               6   261.5400     Regular Air  -213.250
# 1         6 2012-02-20               2     6.9300     Regular Air    -4.640
# 2        32 2011-07-15              26  2808.0800     Regular Air  1054.820
# 3        32 2011-07-15              24  1761.4000  Delivery Truck -1748.560
# 4        32 2011-07-15              23   160.2335     Regular Air   -85.129
#
#    Unit Price       Customer Name Customer Segment Product Category
# 0       38.94  Muhammed MacIntyre   Small Business  Office Supplies
# 1        2.08         Ruben Dartt        Corporate  Office Supplies
# 2      107.53       Liz Pelletier        Corporate        Furniture
# 3       70.89       Liz Pelletier        Corporate        Furniture
# 4        7.99       Liz Pelletier        Corporate       Technology

# %%
df.describe()
# Out:
#           Order ID                     Order Date  Order Quantity  \
# count  1007.000000                           1007     1007.000000
# mean   3478.923535  2010-12-24 04:24:32.889771776       24.832175
# min       3.000000            2008-07-15 00:00:00        1.000000
# 25%    1665.500000            2010-01-05 00:00:00       12.000000
# 50%    3456.000000            2010-12-24 00:00:00       25.000000
# 75%    5350.000000            2012-01-04 00:00:00       38.000000
# max    7239.000000            2012-12-28 00:00:00       50.000000
# std    2119.704215                            NaN       14.367466
#
#               Sales        Profit   Unit Price
# count    999.000000    999.000000  1007.000000
# mean    1869.035668    216.914564    91.255045
# min        2.240000  -4266.088500     1.260000
# 25%      132.465000    -83.495000     6.480000
# 50%      412.620000     -1.250000    20.970000
# 75%     1695.515000    146.608000    95.950000
# ...

# %% [markdown]
# ### Exploring Cleaned Data

# %%
clean_df = pd.read_excel("../cleanedData/cleaned_Orders-With Nulls.xlsx")

# %%
clean_df.head()
# Out:
#    Order ID Order Date  Order Quantity      Sales       Ship Mode    Profit  \
# 0         3 2010-10-13               6   261.5400     Regular Air -213.2500
# 1         6 2012-02-20               2     6.9300     Regular Air   -4.6400
# 2        32 2011-07-15              26  2808.0800     Regular Air  491.7625
# 3        32 2011-07-15              24  1761.4000  Delivery Truck -428.6495
# 4        32 2011-07-15              23   160.2335     Regular Air  -85.1290
#
#    Unit Price       Customer Name Customer Segment Product Category
# 0       38.94  Muhammed Macintyre   Small Business  Office Supplies
# 1        2.08         Ruben Dartt        Corporate  Office Supplies
# 2      107.53       Liz Pelletier        Corporate        Furniture
# 3       70.89       Liz Pelletier        Corporate        Furniture
# 4        7.99       Liz Pelletier        Corporate       Technology

# %%
clean_df.describe()
# Out:
#           Order ID                     Order Date  Order Quantity  \
# count   999.000000                            999      999.000000
# mean   3506.483483  2010-12-30 22:21:58.918919168       24.820821
# min       3.000000            2009-01-05 00:00:00        1.000000
# 25%    1761.500000            2010-01-13 00:00:00       12.000000
# 50%    3460.000000            2010-12-25 00:00:00       25.000000
# 75%    5379.500000            2012-01-04 12:00:00       38.000000
# max    7239.000000            2012-12-28 00:00:00       50.000000
# std    2105.577835                            NaN       14.399014
#
#              Sales      Profit  Unit Price
# count   999.000000  999.000000  999.000000
# mean   1147.468841   43.677269   59.441396
# min       2.240000 -428.649500    1.260000
# 25%     132.465000  -83.495000    6.480000
# 50%     412.620000   -1.250000   20.970000
# 75%    1695.515000  146.608000   95.690000
# max    4040.090000  491.762500  229.505000
# ...
